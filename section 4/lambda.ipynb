# %% [markdown]
# # Lambda Functions
#
# lambda هي طريقة مختصرة لكتابة دالة صغيرة من سطر واحد، وتكون مناسبة عندما يكون السلوك بسيطاً جداً.

# %%
def square(number):
    return number ** 2

square_lambda = lambda number: number ** 2

print(square(5))
print(square_lambda(5))

# %%
students = [
    {"name": "Ali", "score": 88},
    {"name": "Mona", "score": 95},
    {"name": "Omar", "score": 82}
]

sorted_students = sorted(students, key=lambda student: student["score"], reverse=True)
print(sorted_students)

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda number: number ** 2, numbers))
even_numbers = list(filter(lambda number: number % 2 == 0, numbers))

print(squared_numbers)
print(even_numbers)

# %% [markdown]
# ## متى لا أستخدم lambda؟
#
# إذا أصبح التعبير طويلاً أو غير واضح فالأفضل استخدام def لأن الوضوح أهم من الاختصار.
