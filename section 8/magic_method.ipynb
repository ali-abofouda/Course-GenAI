# %%
# ## magic method is a special method that is defined in a class and is called automatically when a certain operation is performed on an object of that class. These methods are also known as dunder methods (double underscore methods) because they are defined with double underscores before and after the method name. Some common magic methods include:
# ## 1. __init__: This method is called when an object is created and is used to initialize the object's attributes.
# ## 2. __str__: This method is called when the str() function is called on
# ##    an object and is used to return a string representation of the object.
# ## 3. __repr__: This method is called when the repr() function is called on an object and is used to return a string representation of the object that can be used to recreate the object.
# ## 4. __add__: This method is called when the + operator is used on two objects and is used to define the behavior of the addition operation for those objects.
# ## 5. __len__: This method is called when the len() function is called on
# ##    an object and is used to return the length of the object.

# class MyClass:
#     def __init__(self, value):
#         self.value = value  # public member
    
#     def __str__(self):
#         return f"MyClass with value: {self.value}"
    
#     def __repr__(self):
#         return f"MyClass({self.value})"
    
#     def __add__(self, other):
#         if isinstance(other, MyClass):
#             return MyClass(self.value + other.value)
#         return NotImplemented
    
#     def __len__(self):
#         return len(str(self.value))
# obj1 = MyClass(10)
# print(obj1)  # Output: MyClass with value: 10
# print(repr(obj1))  # Output: MyClass(10)
# obj2 = MyClass(20)
# obj3 = obj1 + obj2
# print(obj3)  # Output: MyClass with value: 30
# print(len(obj1))  # Output: 2 (length of the string "10")
# print(len(obj2))  # Output: 2 (length of the string "20")
# print(len(obj3))  # Output: 2 (length of the string "30")
# Out:
# MyClass with value: 10
# MyClass(10)
# MyClass with value: 30
# 2
# 2
# 2

# %%
class MyClass:
    def __init__(self , value):
        self.value = value

    def __len__(self):
        return len(str(self.value))
    
    def __str__(self):
        return f"my class has value {self.value}"
    

class1 = MyClass(5)

print(class1)
# Out:
# my class has value 5
