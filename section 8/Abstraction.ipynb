# %% [markdown]
# # Abstraction
#
# التجريد يعني تقديم واجهة بسيطة وواضحة للمستخدم وإخفاء التفاصيل الداخلية غير الضرورية.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

class CreditCardPayment(PaymentMethod):
    def pay(self, amount):
        print(f"Paid {amount} using a credit card.")

class PayPalPayment(PaymentMethod):
    def pay(self, amount):
        print(f"Paid {amount} using PayPal.")

payments = [CreditCardPayment(), PayPalPayment()]
for payment in payments:
    payment.pay(250)

# %% [markdown]
# ## ماذا نتعلم من المثال؟
#
# - يوجد عقد واضح اسمه pay.
# - كل فئة فرعية تنفذ نفس الفكرة بطريقتها.
# - الكود الخارجي لا يحتاج معرفة التفاصيل الداخلية لكل وسيلة دفع.
