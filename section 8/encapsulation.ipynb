# %% [markdown]
# # Encapsulation
#
# التغليف يعني حماية البيانات داخل الكائن والتحكم في طريقة الوصول إليها أو تعديلها.

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self._balance = balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self._balance:
            self._balance -= amount

    def get_balance(self):
        return self._balance

account = BankAccount("Ali", 1000)
account.deposit(200)
account.withdraw(150)
print(account.get_balance())

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.__salary = salary

    def set_salary(self, salary):
        if salary >= 0:
            self.__salary = salary

    def get_salary(self):
        return self.__salary

employee = Employee("Mona", 8000)
employee.set_salary(9000)
print(employee.get_salary())

# %% [markdown]
# ## ملاحظات
#
# - الاسم الذي يبدأ بشرطة سفلية واحدة يعني أنه داخلي.
# - الاسم الذي يبدأ بشرطتين سفليتين يقلل الوصول المباشر.
# - الأفضل توفير methods أو properties لضبط القواعد.
