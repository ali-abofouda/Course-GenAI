# %%
# exception handling in python
try:    # code that may raise an exception
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print(f"The result of {num1} divided by {num2} is: {result}")
except ValueError:
    print("Please enter valid integers.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# The result of 10 divided by 20 is: 0.5

# %%
a = int(input("please enter the first number for devision"))
b = int(input("please enter the seconed number for devision"))

try: 
    result = a / b 
    print(f"the resullt is {result}")
except ValueError:
    print("please enter a valid number ")
except ZeroDivisionError:
    print("Error : zero error")
# Out:
# Error : zero error

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num

except ValueError:
    print("Please enter a valid integer.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

else:
    print(f"The result of 10 divided by {num} is: {result}")

finally:
    print("This block will always execute, regardless of exceptions.")
# Out:
# Please enter a valid integer.
# This block will always execute, regardless of exceptions.

# %%
with open("non_existent_file.txt", "w") as file:
    file.write("Hello, World!")
    print("File written successfully.")
# Out:
# File written successfully.

# %%
# file handling with exception handling
try:
    with open("non_existent_file.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("The file was not found. Please check the file name and try again.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
finally:
    print("Finished attempting to read the file.")
# Out:
# Hello, World!
