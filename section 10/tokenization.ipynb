# %% [markdown]
# # Tokenization
#
# التقسيم هو أول خطوة تقريباً في معالجة اللغة الطبيعية، وفيه نحول النص إلى جمل أو كلمات أصغر.

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# Run these downloads once if the resources are missing.
# nltk.download("punkt")
# nltk.download("punkt_tab")

# %%
text = "Hello, my name is Ali. I enjoy learning NLP. Python makes experimentation easier."
print(text)

# %%
sentences = sent_tokenize(text)
print(sentences)

for sentence in sentences:
    print(word_tokenize(sentence))

# %% [markdown]
# ## لماذا هذه الخطوة أساسية؟
#
# بعد تقسيم النص يصبح من السهل العد والتنظيف والتحليل النحوي وبناء السمات التي ستستخدمها النماذج لاحقاً.
