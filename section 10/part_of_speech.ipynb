# %% [markdown]
# # Part of Speech Tagging
#
# تحديد نوع الكلمة يعني تصنيفها بحسب دورها النحوي مثل اسم أو فعل أو صفة.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Run these downloads once if the resources are missing.
# nltk.download("punkt")
# nltk.download("punkt_tab")
# nltk.download("averaged_perceptron_tagger")
# nltk.download("averaged_perceptron_tagger_eng")

# %%
sentence = "The quick brown fox jumps over the lazy dog"
tokens = word_tokenize(sentence)
print(tokens)

# %%
tagged_tokens = pos_tag(tokens)
print(tagged_tokens)

for word, tag in tagged_tokens:
    print(f"{word:<10} -> {tag}")

# %% [markdown]
# ## الفائدة
#
# بعد معرفة نوع كل كلمة يصبح من الأسهل استخراج الأسماء والأفعال المهمة وبناء مراحل تحليل لاحقة.
